# %% [markdown]
# # Creating a Custom Dataset for your files

# %% [markdown]
# A custom Dataset class must implement three functions: __init__, __len__, and __getitem__.

# %%
import os
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class MoleculeDataset(Dataset):
    def __init__(self):
        self.data = pd.read_csv('YourData.csv')
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        smiles = self.data['SMILES'].iloc[idx]
        target = self.data['Target'].iloc[idx]
        # You can do transformations here if needed like convert SMILES to graph.
        # "https://github.com/Harrison-Li/Practice_MolGNN/blob/main/train/dataset.py"
        return smiles, target

# %% [markdown]
# #  __init__
#
# The __init__ function is run once when instantiating the Dataset object. We initialize the data directory, the annotations file, and both transforms (covered in more detail in the next section).

# %% [markdown]
# # __getitem__
#
# The __getitem__ function loads and returns a sample from the dataset at the given index idx

# %% [markdown]
# # Preparing your data for training with DataLoaders
#
# The Dataset retrieves our dataset’s features and labels one sample at a time. While training a model, we typically want to pass samples in “minibatches”, reshuffle the data at every epoch to reduce model overfitting, and use Python’s $\underline{multiprocessing}$ to speed up data retrieval.
#
# DataLoader is an iterable that abstracts this complexity for us in an easy API

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=True)
